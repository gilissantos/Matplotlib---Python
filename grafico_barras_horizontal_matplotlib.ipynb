# %% [markdown]
# <a href="https://colab.research.google.com/github/gilissantos/Matplotlib---Python/blob/master/grafico_barras_horizontal_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p><img alt="Colaboratory logo" height="15px" src="https://i2.wp.com/comofazer.site/wp-content/uploads/2020/03/1583871068_612_Como-usar-graficos-Tipos-e-qual-usar-grafico-de.png?resize=621%2C391" align="left" hspace="4px" vspace="0px"></p>
#
# <h1>Gráfico de Barras horizontal com Python/Matplotlib</h1>
# <br>
# <p>
# O gráfico de barras horizontal é simplificado com a bliboteca Matplotlib. Neste exemplo vamos criar um Data Frame das seleções que ganharam títulos da Copa do Mundo de Futebol.
#
# É utilizado para mostrar o valor de uma determinada categoria, em nosso exemplo vamos verificar a soma de títulos das seleções de futebol, o valor agregado da soma de cada seleção separadamente.
# Para maiores informações sobre o gráfico de barras, visite a página <a href="https://matplotlib.org/3.2.1/api/_as_gen/matplotlib.pyplot.bar.html">oficial da biblioteca Matplotlib</a>. Vamos ao código!
# </p>

# %%
# Importando as bibliotecas Mataplotlib e Pandas
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Para este exemplo vamos utlizar uma quadro de dados com as receitas de 5 marcas:

receita = {
    "marca": ["apple", "google", "microsoft", "amazon", "facebook"],
    "receita": [205.5, 167.7, 125.3, 88.9, 97]
}

# %%
# Vamos transforma o objeto vendas em um data frame e chamá-lo de df:

df = pd.DataFrame(receita)

df
# Out:
#        marca  receita
# 0      apple    205.5
# 1     google    167.7
# 2  microsoft    125.3
# 3     amazon     88.9
# 4   facebook     97.0

# %%
# Vamos criar o gráfico de barras:

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.barh(df["marca"], df["receita"], color="lightseagreen")
ax.set_title("Top 5 receitas - Marcas")
ax.set_xlabel("Marcas")
ax.set_ylabel("USD - Bilhões")
plt.show()
